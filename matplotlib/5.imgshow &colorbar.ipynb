# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.image as mpimg

# %%
img=mpimg.imread("pic chart.png")

# %%
img
# Out:
# array([[[0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         ...,
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ]],
#
#        [[0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         ...,
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ]],
#
#        [[0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         ...,
#         [0.       , 0.5019608, 0.       , 1.       ],
# ...

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (400, 600, 4)

# %%
img.ndim
# Out:
# 3

# %%
plt.imshow(img)

# %%
plt.imshow(img,)
plt.axis("off")
plt.colorbar()

# %%
plt.figure(figsize=(16,9))
img2=mpimg.imread("C:\\Users\\Aakansha\\Documents\\home\\matpoltlib\\1.jpg")
plt.imshow(img2)
plt.axis("off")
plt.show()

# %%
singl_channel=img2[:,:,1]
plt.figure(figsize=(16,9))
img2=mpimg.imread("C:\\Users\\Aakansha\\Documents\\home\\matpoltlib\\1.jpg")
plt.imshow(singl_channel,cmap="hot")
plt.axis("off")
plt.show()

# %%
singl_channel=img2[:,:,1]
plt.figure(figsize=(16,9))
img2=mpimg.imread("E:\\a polytechinc\\ghumi photo\\tungnath30may\\1.jpg")
plt.imshow(singl_channel,cmap="nipy_spectral")
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-3d509e75db08> in <module>
# ----> 1 singl_channel=img2[:,:,1]
#       2 plt.figure(figsize=(16,9))
#       3 img2=mpimg.imread("E:\\a polytechinc\\ghumi photo\\tungnath30may\\1.jpg")
#       4 plt.imshow(singl_channel,cmap="nipy_spectral")
#       5 plt.axis("off")
#
# NameError: name 'img2' is not defined
