# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# Out:
# C:\Users\Aakansha\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
tips=sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(x=tips["day"],y=tips["total_bill"])

# %%
sns.barplot(x=tips["day"],y=tips["total_bill"],hue=tips["sex"])

# %%
sns.barplot(x="day",y="total_bill",hue="sex",data=tips)
#data use to we are not use datafrane agian and again

# %%
order = ["sun", "thue", "fri", "sat"]

sns.barplot(x="day",y="total_bill",hue="sex",
            data = tips, order = order)
# i don't no why are data not show

# %%
sns.barplot(x="day",y="total_bill",hue="sex",data=tips,
            estimator=np.max)

# %%
sns.barplot(x="day",y="total_bill",hue="sex",data=tips,
           estimator=np.max,ci=31)

# %%
sns.barplot(y="day",x="total_bill",hue="sex",data=tips,)
#without orient with plot data horigentally only one case
#wwhen x data are numarical

# %%
#when both are numberiacal the use orient
sns.barplot(x="total_bill",y="size",hue="sex",data=tips, orient="h" )

# %%
sns.barplot(x="day",y="total_bill",hue='sex',data=tips,color="g")

# %%
sns.barplot(x="day",y="total_bill",hue='sex',data=tips,palette="hot")

# %%
sns.barplot(x="day",y="total_bill",hue='sex',data=tips,saturation=0.3)

# %%
sns.barplot(x="day",y="total_bill",hue='sex',data=tips,errcolor="0.5")

# %%
sns.barplot(x="day",y="total_bill",hue='sex',data=tips,errwidth=12)

# %%
sns.barplot(x="day",y="total_bill",hue='sex',data=tips,capsize=1)

# %%
sns.barplot(x="day",y="total_bill",hue='sex',data=tips,dodge=False)

# %%
sns.set()
kwargs={'alpha':0.9,'linestyle':':','linewidth':5,'edgecolor':'black'}
sns.barplot(x="day",y="total_bill",data=tips,**kwargs)

# %%
#two type use to keyword argument
sns.barplot(x="day",y="total_bill",data=tips,alpha=0.9,
            linestyle="-.",linewidth=6,edgecolor="g")

# %%
ax=sns.barplot(x="day",y="total_bill",data=tips,alpha=0.9,
            linestyle="-.",linewidth=6,edgecolor="g")
ax.set(title="barplot of topic DataFrame",
      xlabel="Days",
      ylabel="Total bill")
# Out:
# [Text(0, 0.5, 'Total bill'),
#  Text(0.5, 0, 'Days'),
#  Text(0.5, 1.0, 'barplot of topic DataFrame')]

# %%
plt.figure(figsize=(16,9))
sns.barplot(x="day",y="total_bill",data=tips,alpha=0.9,
            linestyle="-.",linewidth=6,edgecolor="g")
plt.title("barplot day and totle bill",fontsize=20)
plt.xlabel("Days",fontsize=20)
plt.ylabel("totle bill",fontsize=20)
plt.show()
